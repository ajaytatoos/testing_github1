# %%
Hardware is the physical part of a computer that you can touch, such as a keyboard, monitor, or processor. Software is the set of programs and instructions that tell the hardware what to do. For example, a keyboard is hardware, while Windows 11 is software.
